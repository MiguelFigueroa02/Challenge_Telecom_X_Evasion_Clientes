# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelFigueroa02/Challenge_Telecom_X_Evasion_Clientes/blob/main/telecomx_latam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %% [markdown]
# ## Conociendo los datos

# %% [markdown]
# ### Carga de la información

# %%
import pandas as pd
import requests

# %%
datos = pd.read_json('https://raw.githubusercontent.com/MiguelFigueroa02/Challenge_Telecom_X_Evasion_Clientes/refs/heads/main/TelecomX_Data.json')

# %%
datos.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# Vamos a asegurarnos que la columna CustomerID no cuente con registros duplicados

# %%
datos['customerID'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No se encuentran registros duplicados

# %%
datos['customerID'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Para empezar, hago un análisis sobre la columna Churn

# %%
datos['Churn'].unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %% [markdown]
# Para detectar valores positivos, negativos y nulos, se convierte resultados a tipo booleano y los resultados vaciios se convierten a null

# %%
datos['Churn'] = datos['Churn'].replace('Yes',True).replace('No',False)

# %%
datos['Churn'] = datos['Churn'].replace('',None)

# %%
datos['Churn'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Churn
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %% [markdown]
# Se detectan 223 valores vacíos, los cuales se convierten a nulos.

# %% [markdown]
# Se normalizan valores en columna Customer

# %%
customer_normalizado = pd.json_normalize(datos['customer'])
customer_normalizado
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %% [markdown]
# Verifico el tipo de datos únicos para determinar el tratamiento a realizar

# %%
columnas_customer = list(customer_normalizado.columns)
columnas_customer
for columna in columnas_customer:
  print(f'En la columna {columna} se encuentran los siguientes valores únicos: {customer_normalizado[columna].unique()}')
# Out:
# En la columna gender se encuentran los siguientes valores únicos: ['Female' 'Male']
# En la columna SeniorCitizen se encuentran los siguientes valores únicos: [0 1]
# En la columna Partner se encuentran los siguientes valores únicos: ['Yes' 'No']
# En la columna Dependents se encuentran los siguientes valores únicos: ['Yes' 'No']
# En la columna tenure se encuentran los siguientes valores únicos: [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
#   0]

# %%
customer_normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB

# %% [markdown]
# Se hacen las modificaciones necesarias para que las columnas SeniorCitizen, Parter y Dependents se conviertan a tipo booleano para estandarizarlo.

# %%
customer_normalizado['SeniorCitizen'] = customer_normalizado['SeniorCitizen'].replace(0,False).replace(1,True)
# Out:
# <ipython-input-54-760472485bf6>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   customer_normalizado['SeniorCitizen'] = customer_normalizado['SeniorCitizen'].replace(0,False).replace(1,True)

# %%
customer_normalizado['Partner'] = customer_normalizado['Partner'].replace('Yes',True).replace('No',False)
# Out:
# <ipython-input-55-fa5fee16e496>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   customer_normalizado['Partner'] = customer_normalizado['Partner'].replace('Yes',True).replace('No',False)

# %%
customer_normalizado['Dependents'] = customer_normalizado['Dependents'].replace('Yes',True).replace('No',False)
# Out:
# <ipython-input-56-f052cb3458b7>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   customer_normalizado['Dependents'] = customer_normalizado['Dependents'].replace('Yes',True).replace('No',False)

# %%
customer_normalizado.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure
# 0  Female          False     True        True       9
# 1    Male          False    False       False       9
# 2    Male          False    False       False       4
# 3    Male           True     True       False      13
# 4  Female           True     True       False       3

# %% [markdown]
# Se cambia nombre de columna ternure

# %%
customer_normalizado['meses_contrato'] = customer_normalizado['tenure']
customer_normalizado.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  meses_contrato
# 0  Female          False     True        True       9               9
# 1    Male          False    False       False       9               9
# 2    Male          False    False       False       4               4
# 3    Male           True     True       False      13              13
# 4  Female           True     True       False       3               3

# %%
customer_normalizado = customer_normalizado.drop('tenure',axis=1)

# %%
customer_normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gender          7267 non-null   object
#  1   SeniorCitizen   7267 non-null   bool
#  2   Partner         7267 non-null   bool
#  3   Dependents      7267 non-null   bool
#  4   meses_contrato  7267 non-null   int64
# dtypes: bool(3), int64(1), object(1)
# memory usage: 135.0+ KB

# %% [markdown]
# Ejecución sobre columna Phone

# %%
phone_normalizado = pd.json_normalize(datos['phone'])
phone_normalizado
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
phone_normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   object
#  1   MultipleLines  7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB

# %% [markdown]
# Verifico resultados únicos

# %%
phone_normalizado['PhoneService'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
phone_normalizado['PhoneService'] = phone_normalizado['PhoneService'].replace('Yes',True).replace('No',False)
# Out:
# <ipython-input-68-280cd842a68b>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   phone_normalizado['PhoneService'] = phone_normalizado['PhoneService'].replace('Yes',True).replace('No',False)

# %%
phone_normalizado['MultipleLines'].unique()
# Out:
# array(['No', 'Yes', 'No phone service'], dtype=object)

# %% [markdown]
# Entendiendo que las columnas con valor 'No phone service' no cuentan con sericio de internet, se modifica para obtener valores booleanos

# %%
phone_normalizado['MultipleLines'] = phone_normalizado['MultipleLines'].replace('Yes',True).replace('No',False).replace('No phone service',False)
# Out:
# <ipython-input-71-a778775c8932>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   phone_normalizado['MultipleLines'] = phone_normalizado['MultipleLines'].replace('Yes',True).replace('No',False).replace('No phone service',False)

# %%
phone_normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   bool
#  1   MultipleLines  7267 non-null   bool
# dtypes: bool(2)
# memory usage: 14.3 KB

# %%
internet_normalizado = pd.json_normalize(datos['internet'])
internet_normalizado
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
internet_normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   object
#  2   OnlineBackup      7267 non-null   object
#  3   DeviceProtection  7267 non-null   object
#  4   TechSupport       7267 non-null   object
#  5   StreamingTV       7267 non-null   object
#  6   StreamingMovies   7267 non-null   object
# dtypes: object(7)
# memory usage: 397.5+ KB

# %%
account_normalizado = pd.json_normalize(datos['account'])
account_normalizado

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
